# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Zeel'

# %%
import os
os.chdir(r"E:\Data Sci\Python\Pandas")
os.getcwd()
# Out:
# 'E:\\Data Sci\\Python\\Pandas'

# %%
pd.read_excel("Python_Pandastopic_a.xlsx")
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
#For printing the records first five through head
sales=pd.read_excel("Python_Pandastopic_a.xlsx")
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
sales.loc[:,['Region','Sales_Channel','Order_Priority']]
# Out:
#                                Region Sales_Channel Order_Priority
# 0               Australia and Oceania       Offline              H
# 1   Central America and the Caribbean        Online              C
# 2                              Europe       Offline              L
# 3                  Sub_Saharan Africa        Online              C
# 4                  Sub_Saharan Africa       Offline              L
# ..                                ...           ...            ...
# 95                 Sub_Saharan Africa        Online              M
# 96                               Asia       Offline              L
# 97                 Sub_Saharan Africa       Offline              C
# 98                      North America       Offline              M
# 99                 Sub_Saharan Africa       Offline              L
#
# [100 rows x 3 columns]

# %%
sales.loc[0:4,['Region']]
# Out:
#                               Region
# 0              Australia and Oceania
# 1  Central America and the Caribbean
# 2                             Europe
# 3                 Sub_Saharan Africa
# 4                 Sub_Saharan Africa

# %%
#For all columns
sales.loc[0:4]
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
#For printing row with some condition
sales
sales[sales.Sales_Channel == "Offline"]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 2                              Europe                 Russia  Office Supplies
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 6                  Sub_Saharan Africa                 Angola        Household
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 11                 Sub_Saharan Africa             Cape Verde          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 14                               Asia               Mongolia    Personal Care
# 16                               Asia              Sri Lanka        Cosmetics
# 17                 Sub_Saharan Africa               Cameroon        Beverages
# 18                               Asia           Turkmenistan        Household
# ...

# %%
#For writing multiple condition
sales[(sales.Total_Profit >= 150000) & (sales.Total_Revenue >=50000)].head()
# Out:
#                               Region          Country        Item_Type  \
# 0              Australia and Oceania           Tuvalu        Baby Food
# 1  Central America and the Caribbean          Grenada           Cereal
# 2                             Europe           Russia  Office Supplies
# 4                 Sub_Saharan Africa           Rwanda  Office Supplies
# 5              Australia and Oceania  Solomon Islands        Baby Food
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 4       Offline              L 2013-06-02     524.96     3296425.02
# 5        Online              C 2015-02-21     159.42      759202.72
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 4     639077.50
# 5     285087.64

# %%
sales[(sales.Order_Priority == 'L')]
# Out:
#                                Region         Country        Item_Type  \
# 2                              Europe          Russia  Office Supplies
# 4                  Sub_Saharan Africa          Rwanda  Office Supplies
# 12                               Asia      Bangladesh          Clothes
# 18                               Asia    Turkmenistan        Household
# 19              Australia and Oceania      East Timor             Meat
# 20                             Europe          Norway        Baby Food
# 22  Central America and the Caribbean        Honduras           Snacks
# 24                             Europe        Moldova     Personal Care
# 27                 Sub_Saharan Africa            Mali           Fruits
# 29                 Sub_Saharan Africa      The Gambia        Household
# 35  Central America and the Caribbean      Costa Rica    Personal Care
# 36       Middle East and North Africa           Syria           Fruits
# ...

# %%
sales[(sales.Sales_Channel == 'Online') & ((sales.Order_Priority == 'L') | (sales.Order_Priority == 'H'))]
# Out:
#                                Region         Country        Item_Type  \
# 7                  Sub_Saharan Africa    Burkina Faso       Vegetables
# 9                  Sub_Saharan Africa         Senegal           Cereal
# 10                               Asia      Kyrgyzstan       Vegetables
# 12                               Asia      Bangladesh          Clothes
# 19              Australia and Oceania      East Timor             Meat
# 20                             Europe          Norway        Baby Food
# 21                             Europe        Portugal        Baby Food
# 22  Central America and the Caribbean        Honduras           Snacks
# 23              Australia and Oceania     New Zealand           Fruits
# 24                             Europe        Moldova     Personal Care
# 25                             Europe          France        Cosmetics
# 27                 Sub_Saharan Africa            Mali           Fruits
# ...

# %%
sales.mean()
# Out:
# <ipython-input-24-91335213504a>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sales.mean()
# Unit_Cost        1.910480e+02
# Total_Revenue    1.373488e+06
# Total_Profit     4.416820e+05
# dtype: float64

# %%
sales.median()
# Out:
# <ipython-input-25-a8878e130716>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sales.median()
# Unit_Cost           107.275
# Total_Revenue    752314.360
# Total_Profit     290767.995
# dtype: float64

# %%
sales.describe()
#75% of given data is below this no 263.330000
# Out:
#         Unit_Cost  Total_Revenue  Total_Profit
# count  100.000000   1.000000e+02  1.000000e+02
# mean   191.048000   1.373488e+06  4.416820e+05
# std    188.208181   1.460029e+06  4.385379e+05
# min      6.920000   4.870260e+03  1.258020e+03
# 25%     35.840000   2.687212e+05  1.214436e+05
# 50%    107.275000   7.523144e+05  2.907680e+05
# 75%    263.330000   2.212045e+06  6.358288e+05
# max    524.960000   5.997055e+06  1.719922e+06

# %%
sales.info()
#Varchar is equal to Object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item_Type       100 non-null    object
#  3   Sales_Channel   100 non-null    object
#  4   Order_Priority  100 non-null    object
#  5   Ship_Date       100 non-null    datetime64[ns]
#  6   Unit_Cost       100 non-null    float64
#  7   Total_Revenue   100 non-null    float64
#  8   Total_Profit    100 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 7.2+ KB

# %%
#check datatype
sales.dtypes['Region']
# Out:
# dtype('O')

# %%
sales.dtypes['Total_Profit']
# Out:
# dtype('float64')

# %%
sales.count()
# Out:
# Region            100
# Country           100
# Item_Type         100
# Sales_Channel     100
# Order_Priority    100
# Ship_Date         100
# Unit_Cost         100
# Total_Revenue     100
# Total_Profit      100
# dtype: int64

# %%
# skew() function return unbiased skew over requested axis
sales.skew()
# Out:
# Unit_Cost        0.858072
# Total_Revenue    1.277698
# Total_Profit     1.238555
# dtype: float64

# %%
#kurt() function return unbiased kurtosis over requested axis
sales.kurt()
# Out:
# Unit_Cost       -0.830099
# Total_Revenue    0.804539
# Total_Profit     0.767398
# dtype: float64

# %%
#Compute pairwise correlation of columns, excluding NA/null values. 
sales.corr()
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost       1.000000       0.715623      0.467214
# Total_Revenue   0.715623       1.000000      0.897327
# Total_Profit    0.467214       0.897327      1.000000

# %%
#Covariance is a measure of how much two random variables vary together.
#The cov() function is used to compute pairwise covariance of columns, excluding NA/null values. 
sales.cov()
# Out:
#                   Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost      3.542232e+04   1.966455e+08  3.856216e+07
# Total_Revenue  1.966455e+08   2.131684e+12  5.745386e+11
# Total_Profit   3.856216e+07   5.745386e+11  1.923155e+11

# %%
sales.max()
# Out:
# Region             Sub_Saharan Africa
# Country                        Zambia
# Item_Type                  Vegetables
# Sales_Channel                  Online
# Order_Priority                      M
# Ship_Date         2017-06-17 00:00:00
# Unit_Cost                      524.96
# Total_Revenue              5997054.98
# Total_Profit               1719922.04
# dtype: object

# %%
sales['Region'].value_counts()
# Out:
# Sub_Saharan Africa                   36
# Europe                               22
# Asia                                 11
# Australia and Oceania                11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: Region, dtype: int64

# %%
#in apply function max,min is used but sum,mean and median is used only for numerical error

# %%
#For deleting according to row
newdata = sales.drop(sales[sales.Order_Priority == 'L'].index)
newdata.head()
# Out:
#                               Region                Country  Item_Type  \
# 0              Australia and Oceania                 Tuvalu  Baby Food
# 1  Central America and the Caribbean                Grenada     Cereal
# 3                 Sub_Saharan Africa  Sao Tome and Principe     Fruits
# 5              Australia and Oceania        Solomon Islands  Baby Food
# 6                 Sub_Saharan Africa                 Angola  Household
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 3        Online              C 2014-05-07       6.92       75591.66
# 5        Online              C 2015-02-21     159.42      759202.72
# 6       Offline              M 2011-04-27     502.54     2798046.49
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 3      19525.82
# 5     285087.64
# 6     693911.51

# %%
sales[sales.Order_Priority == 'L']
# Out:
#                                Region         Country        Item_Type  \
# 2                              Europe          Russia  Office Supplies
# 4                  Sub_Saharan Africa          Rwanda  Office Supplies
# 12                               Asia      Bangladesh          Clothes
# 18                               Asia    Turkmenistan        Household
# 19              Australia and Oceania      East Timor             Meat
# 20                             Europe          Norway        Baby Food
# 22  Central America and the Caribbean        Honduras           Snacks
# 24                             Europe        Moldova     Personal Care
# 27                 Sub_Saharan Africa            Mali           Fruits
# 29                 Sub_Saharan Africa      The Gambia        Household
# 35  Central America and the Caribbean      Costa Rica    Personal Care
# 36       Middle East and North Africa           Syria           Fruits
# ...

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}, 
                    index = [0, 1, 2, 3]) 
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'], 
                    'D': ['D4', 'D5', 'D6', 'D7']}, 
                    index = [0,1,2,3]) 
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'], 
                    'B': ['B8', 'B9', 'B10', 'B11'], 
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']}, 
                    index = [0,1,2,3]) 
df3
# Out:
#      A    B    C    D
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %%
df=[df1,df2,df3]

# %%
for i in df:
    i.reset_index(drop=True,inplace=True)

# %%
pd.concat(df,axis=1)
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  A0  B0  C0  D0  A4  B4  C4  D4   A8   B8   C8   D8
# 1  A1  B1  C1  D1  A5  B5  C5  D5   A9   B9   C9   D9
# 2  A2  B2  C2  D2  A6  B6  C6  D6  A10  B10  C10  D10
# 3  A3  B3  C3  D3  A7  B7  C7  D7  A11  B11  C11  D11
