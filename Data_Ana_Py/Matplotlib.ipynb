# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
plt.plot([11, 22, 33, 400])
plt.ylabel('some numbers')
#If we want to show only image if we dont write then it also shows the object
plt.show()

# %%
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
print(xpoints)
print(ypoints)
plt.plot(xpoints, ypoints)
plt.show()
# Out:
# [0 6]
# [  0 250]

# %%
x = [5, 2, 9, 4, 7]   
y = [10, 5, 8, 4, 2] 
plt.plot(x,y) 
plt.show()

# %% [markdown]
# # Formatting style

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'o') # try ro
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)
print(t)
# red dashes, blue squares and green triangles
#Here t**2 means t^2 and shows by blue sqaure
#Here t**3 means t^3 and shows by green tri
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %% [markdown]
# # marker style

# %%
ypoints = np.array([2,4,3,6,5,8,7])
plt.plot(ypoints, marker = '*')  #try 0, + , |
plt.show()

# %%
#marker size
plt.plot(ypoints, marker = 'o', ms = 7)
plt.show()

# %%
#marker border
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#changing line style
plt.plot(ypoints, 'o:r') #try - , : , 
plt.show()

# %%
#line style
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %%
#color
plt.plot(ypoints, color = 'hotpink')  #hotpink
plt.show()

# %%
#width
plt.plot(ypoints, linewidth = '2.5')
plt.show()

# %% [markdown]
# # subplot

# %%
x = np.array([2,4,3,6,4,8,7])
y = np.array([1,2,3,4,5,6,7])
#Here 1 means 1-row and 2 col and 1 will be this plot and next will be down one
plt.subplot(1, 2, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([2,4,6,8])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
#plot 1:
x = np.array([2,4,3,6,4,8,7])
y = np.array([1,2,3,4,5,6,7])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([2,4,6,8])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([2,3,4,5])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2,5,3,7])

plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 3)
plt.plot(x,y)

x = np.array([11,12,10,13])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)



#plt.show()

# %%
#Tiles
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Title 1")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Title 2")

plt.show()

# %%
#Main title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([2,5,3,8])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Title 1")

#plot 2:
x = np.array([0, 2,5,3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Tile 2")

plt.suptitle("Main Title")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11])
y = np.array([34,54,64,74,83,65,92,25,75,89])

plt.scatter(x, y)
plt.show()

# %%
#comparing 2 scatter plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

x = np.array([2,2,3,13,11,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,100,100,100,100,100,100,100,100,100,100,100,100,100,100])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# # Bar plot

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,4,6,8])

plt.bar(x,y)
plt.show()

# %%
x = ["USA", "INDIA"]
y = [121, 99]
plt.bar(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([8,6,4,2])
plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([2,4,3,6,5])
plt.bar(x, y, color = "red")
plt.show()

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([2,4,3,6,5])
plt.bar(x, y, color = "hotpink")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,4,6,8])
#bar width
plt.bar(x, y, width = 0.9)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,3,4,5])
plt.barh(x, y, height = 0.6)
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# ### A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc.
# #When we have to use measure VS measure

# %%
#random.normal(loc=0.0, scale=1.0, size=None)
#loc:Mean (“centre”) of the distribution
# scale:Standard deviation (spread or “width”) of the distribution. Must be non-negative.
#size :

x = np.random.normal(150,10, 250)
print(x)
plt.hist(x)
plt.show() 

#mu, sigma = 0, 0.1 # mean and standard deviation
#s = np.random.normal(mu, sigma, 1000)
# Out:
# [153.63718094 155.66674602 147.17105054 156.7795204  151.10268519
#  150.34648708 162.72767081 154.99314711 157.21538646 160.66812841
#  151.37385791 141.43374845 156.68295617 152.01699249 140.31494063
#  158.33526668 164.12899649 152.71913309 143.44623709 164.27695486
#  151.07893573 132.11405795 140.33407735 155.68569014 158.16547746
#  146.43557089 156.83774299 156.06350024 141.15950784 165.09979045
#  149.97547515 157.32165392 145.63388869 149.46888943 136.05969308
#  157.62910643 146.70582465 150.34891045 131.24150797 144.07046426
#  154.09566406 156.55598556 138.5843033  156.59281831 115.99817143
#  138.52397036 158.45239435 156.17428581 154.54269788 159.12462563
#  155.98206088 163.39727645 147.09610401 143.42916424 132.55976651
#  157.79331676 149.11518651 146.45271088 143.0650031  158.3709727
#  135.37906391 164.23766379 159.36217624 154.84192681 147.91552038
#  150.80086109 152.25441037 147.83549886 157.97963083 137.01939144
# ...

# %% [markdown]
# # Pie chart

# %%
y = np.array([20,35,10,45])
plt.pie(y)
plt.show()

# %%
#labels
y = np.array([20,35,10,45])
mylabels = ["USA", "India", "Russia", "China"]
plt.pie(y, labels=mylabels,autopct='%1.1f%%')  # autopct for show percentage
plt.show()

# %%
#angle set
#default is 0
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#explode
myexplode = [0.5, 0.2, 0.1, 0.4]
print(mylabels)
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
# Out:
# ['USA', 'India', 'Russia', 'China']

# %%
#shoadow
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#color
mycolors = ["black", "red", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#legend
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#legend with title
plt.pie(y, labels = mylabels)
plt.legend(title = "Country")
plt.show()

# %% [markdown]
# # Boxplot

# %% [markdown]
# #### Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).

# %%
np.random.seed(10) 
  
data_1 = np.random.normal(100, 10, 200) 
data_2 = np.random.normal(90, 20, 200) 
data_3 = np.random.normal(80, 30, 200) 
data_4 = np.random.normal(70, 40, 200) 
data = [data_1, data_2, data_3, data_4] 
  
fig = plt.figure(figsize =(5, 7)) 
  
# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1]) 
  
# Creating plot 
bp = ax.boxplot(data) 
  
# show plot 
plt.show()
